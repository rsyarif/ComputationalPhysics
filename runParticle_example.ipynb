# %%
from Particle import *

# %%
m = 10
x0 = 20
v0 = 2
tf = 10.0
dt = 0.2
myparticle = FallingParticle(m,x0,v0,tf,dt)
myparticle.Euler_trajectory()
# Out:
# A new particle has been init'd

# %%
myparticle.results()
# Out:
# 	 Position and Velocity at Final Time:
# Euler:
# t = 9.999999999999996 x = -440.2000000000001 v = -95.99999999999991

# %%
myparticle.plot()

# %%
m = 10
x0 = 20
v0 = 2
tf = 10.0
dt = 0.2
myparticle = FallingParticle(m,x0,v0,tf,dt)
myparticle.RK4_trajectory()
# Out:
# A new particle has been init'd

# %%
myparticle.results()
# Out:
# 	 Position and Velocity at Final Time:
# Euler:
# t = 9.999999999999996 x = -449.9999999999999 v = -95.99999999999991

# %%
myparticle.plot()

# %%
m = 10
x0 = 20
v0 = 2
tf = 10.0
dt = 0.2
myparticle = FallingParticle(m,x0,v0,tf,dt)
myparticle.scipy_trajectory()
# Out:
# A new particle has been init'd

# %%
myparticle.results()
# Out:
# 	 Position and Velocity at Final Time:
# Euler:
# t = 0.0 x = 20 v = 2
# SciPy ODE Integrator:
# t = 10.0 x = -450.00000000421096 v = -96.00000000000003

# %%
myparticle.plot()
